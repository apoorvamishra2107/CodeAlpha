# %% [markdown]
# <a href="https://colab.research.google.com/github/apoorvamishra2107/CodeAlpha/blob/main/Car_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# %% [markdown]
# Data gathering and Processing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()
# Out:
#                        name  year  selling_price  ...  seller_type transmission         owner
# 0             Maruti 800 AC  2007          60000  ...   Individual       Manual   First Owner
# 1  Maruti Wagon R LXI Minor  2007         135000  ...   Individual       Manual   First Owner
# 2      Hyundai Verna 1.6 SX  2012         600000  ...   Individual       Manual   First Owner
# 3    Datsun RediGO T Option  2017         250000  ...   Individual       Manual   First Owner
# 4     Honda Amaze VX i-DTEC  2014         450000  ...   Individual       Manual  Second Owner
#
# [5 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()

#rows and columns number
car_dataset.shape
# Out:
# (4340, 8)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()

#rows and columns number
car_dataset.shape

car_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()

#rows and columns number
car_dataset.shape

car_dataset.info()

#checking for missing values
car_dataset.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()

#rows and columns number
car_dataset.shape

car_dataset.info()

#checking for missing values
car_dataset.isnull().sum()

#checking the distribution of categorical data
# Access columns using bracket notation ['column_name']
print(car_dataset['fuel'].value_counts())  # Changed car_dataset.Fuel to car_dataset['fuel']
print(car_dataset['seller_type'].value_counts()) # Changed car_dataset.Seller_Type to car_dataset['seller_type']
print(car_dataset['transmission'].value_counts()) # Changed car.Transmission to car_dataset['transmission']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64

# %% [markdown]
# Encoding Categorical Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()

#rows and columns number
car_dataset.shape

car_dataset.info()

#checking for missing values
car_dataset.isnull().sum()

#checking the distribution of categorical data
# Access columns using bracket notation ['column_name']
print(car_dataset['fuel'].value_counts())  # Changed car_dataset.Fuel to car_dataset['fuel']
print(car_dataset['seller_type'].value_counts()) # Changed car_dataset.Seller_Type to car_dataset['seller_type']
print(car_dataset['transmission'].value_counts()) # Changed car.Transmission to car_dataset['transmission']
#encoding "Fuel" Column
car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)

#encoding "Seller_Type" Column
car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)

#encoding "Transmission" Column
car_dataset.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()

#rows and columns number
car_dataset.shape

car_dataset.info()

#checking for missing values
car_dataset.isnull().sum()

#checking the distribution of categorical data
# Access columns using bracket notation ['column_name']
print(car_dataset['fuel'].value_counts())  # Changed car_dataset.Fuel to car_dataset['fuel']
print(car_dataset['seller_type'].value_counts()) # Changed car_dataset.Seller_Type to car_dataset['seller_type']
print(car_dataset['transmission'].value_counts()) # Changed car.Transmission to car_dataset['transmission']
#encoding "Fuel" Column
car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)

#encoding "Seller_Type" Column
car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)

#encoding "Transmission" Column
car_dataset.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)

car_dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64
# ...

# %% [markdown]
# Splitting into Train and Test

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()

#rows and columns number
car_dataset.shape

car_dataset.info()

#checking for missing values
car_dataset.isnull().sum()

#checking the distribution of categorical data
# Access columns using bracket notation ['column_name']
print(car_dataset['fuel'].value_counts())  # Changed car_dataset.Fuel to car_dataset['fuel']
print(car_dataset['seller_type'].value_counts()) # Changed car_dataset.Seller_Type to car_dataset['seller_type']
print(car_dataset['transmission'].value_counts()) # Changed car.Transmission to car_dataset['transmission']
#encoding "Fuel" Column
car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)

#encoding "Seller_Type" Column
car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)

#encoding "Transmission" Column
car_dataset.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)

car_dataset.head()


#splitting the data and target
X = car_dataset.drop(['name','selling_price'],axis=1)
Y = car_dataset['selling_price']
print(X)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()

#rows and columns number
car_dataset.shape

car_dataset.info()

#checking for missing values
car_dataset.isnull().sum()

#checking the distribution of categorical data
# Access columns using bracket notation ['column_name']
print(car_dataset['fuel'].value_counts())  # Changed car_dataset.Fuel to car_dataset['fuel']
print(car_dataset['seller_type'].value_counts()) # Changed car_dataset.Seller_Type to car_dataset['seller_type']
print(car_dataset['transmission'].value_counts()) # Changed car.Transmission to car_dataset['transmission']
#encoding "Fuel" Column
car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)

#encoding "Seller_Type" Column
car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)

#encoding "Transmission" Column
car_dataset.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)

car_dataset.head()


#splitting the data and target
X = car_dataset.drop(['name','selling_price'],axis=1)
Y = car_dataset['selling_price']
print(Y)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64
# 0        60000
# 1       135000
# 2       600000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

#Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#first five rows
car_dataset.head()

#rows and columns number
car_dataset.shape

car_dataset.info()

#checking for missing values
car_dataset.isnull().sum()

#checking the distribution of categorical data
# Access columns using bracket notation ['column_name']
print(car_dataset['fuel'].value_counts())  # Changed car_dataset.Fuel to car_dataset['fuel']
print(car_dataset['seller_type'].value_counts()) # Changed car_dataset.Seller_Type to car_dataset['seller_type']
print(car_dataset['transmission'].value_counts()) # Changed car.Transmission to car_dataset['transmission']
#encoding "Fuel" Column
car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)

#encoding "Seller_Type" Column
car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)

#encoding "Transmission" Column
car_dataset.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)

car_dataset.head()


#splitting training and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state=2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64
# ...

# %% [markdown]
# Model Training

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

# Encoding "owner" Column
# Create a mapping of unique owner values to numerical values
owner_mapping = {owner: i for i, owner in enumerate(car_dataset['owner'].unique())}
# Replace owner values with numerical values using the mapping
car_dataset['owner'] = car_dataset['owner'].map(owner_mapping)

# Encoding other categorical features:
car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)
car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)
car_dataset.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)


# Splitting the data and target
X = car_dataset.drop(['name', 'selling_price'], axis=1)
Y = car_dataset['selling_price']

# Splitting training and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=2)

# Loading the linear regression model
lin_reg_model = LinearRegression()
lin_reg_model.fit(X_train, Y_train)  # Now the model should fit without the ValueError
# Out:
# <ipython-input-23-2894514a0115>:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)
# <ipython-input-23-2894514a0115>:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)
# ...

# %% [markdown]
# Evaluation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#prediction on training data
training_data_prediction = lin_reg_model.predict(X_train)

#R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.42761668754756255

# %% [markdown]
# Visualization of actual prices and Predicted prices

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

plt.scatter(Y_train, training_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

#prediction on training data
test_data_prediction = lin_reg_model.predict(X_test)

#R squared error
error_score = metrics.r2_score(Y_test, test_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.5031520884182301

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

plt.scatter(Y_test, test_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %% [markdown]
# Lasso Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

#loading the lasso regression model
lass_reg_model = Lasso()
lass_reg_model.fit(X_train,Y_train)
# Out:
# Lasso()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#loading the lasso regression model
lass_reg_model = Lasso()
lass_reg_model.fit(X_train,Y_train)

#prediction on training data
training_data_prediction = lass_reg_model.predict(X_train)

#R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.42761668749407034

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# Load the dataset
car_dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
#loading the lasso regression model
lass_reg_model = Lasso()
lass_reg_model.fit(X_train,Y_train)

#prediction on training data
training_data_prediction = lass_reg_model.predict(X_train)

#R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared Error : ", error_score)

#visualize the actual prices and predicted prices
plt.scatter(Y_train, training_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted Prices")
plt.show()
# Out:
# R squared Error :  0.42761668749407034
